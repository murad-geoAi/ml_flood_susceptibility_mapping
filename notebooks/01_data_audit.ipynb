# %% [markdown]
# # Data Audit
#
# This notebook audits the raw flood susceptibility dataset and reproduces the main dataset insights used in the paper.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import config

# %%
import pandas as pd
from src.data_loader import build_dataset_insight_tables, load_raw_data

raw_frame = load_raw_data(config.RAW_DATA_PATH)
insights = build_dataset_insight_tables(raw_frame)
summary = insights['summary']
summary

# %%
insights['missingness'].head(10)

# %%
insights['lulc_flood_rate']

# %%
insights['correlation'].head(10)

# %%
insights['skewness'].head(10)
