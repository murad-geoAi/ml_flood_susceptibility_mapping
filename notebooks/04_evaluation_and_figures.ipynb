# %% [markdown]
# # Evaluation And Figures
#
# This notebook rebuilds the core tables and publication figures for the classical-model comparison.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import config

# %%
import pandas as pd
from src.evaluate import plot_model_comparison

validation_metrics = pd.read_csv(config.METRICS_DIR / 'validation_model_metrics.csv')
test_metrics = pd.read_csv(config.METRICS_DIR / 'test_model_metrics.csv')
validation_metrics.head()

# %%
test_metrics[['model', 'roc_auc', 'average_precision', 'accuracy', 'balanced_accuracy', 'f1', 'mcc']]

# %%
plot_model_comparison(test_metrics, config.FIGURES_DIR / 'model_comparison.png')
config.FIGURES_DIR / 'model_comparison.png'

# %%
pd.read_csv(config.TABLES_DIR / 'table_validation_summary.csv')

# %%
pd.read_csv(config.TABLES_DIR / 'table_test_summary.csv')
