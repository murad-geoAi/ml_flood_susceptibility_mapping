# %% [markdown]
# # Model Training And Tuning
#
# This notebook benchmarks the classical models under the shared spatial holdout and validation-based threshold selection.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src import config

# %%
from src.data_loader import load_raw_data
from src.preprocessing import prepare_dataset
from src.train_models import benchmark_models

raw_frame = load_raw_data(config.RAW_DATA_PATH)
prepared = prepare_dataset(
    raw_frame=raw_frame,
    target_column=config.TARGET_COLUMN,
    coordinate_columns=config.COORDINATE_COLUMNS,
    categorical_columns=config.CATEGORICAL_COLUMNS,
    cyclical_angle_columns=config.CYCLICAL_ANGLE_COLUMNS,
    spatial_block_size=config.SPATIAL_BLOCK_SIZE,
    spatial_folds=config.SPATIAL_FOLDS,
    validation_fold=config.VALIDATION_FOLD,
    test_fold=config.TEST_FOLD,
    seed=config.SEED,
)
benchmark = benchmark_models(
    prepared=prepared,
    models_dir=config.MODELS_DIR,
    seed=config.SEED,
    n_jobs=1,
    primary_model_name=config.PRIMARY_MODEL_NAME,
    benchmark_model_name=config.BENCHMARK_MODEL_NAME,
)

# %%
benchmark.validation_frame[['model', 'roc_auc', 'average_precision', 'f1']]

# %%
benchmark.test_frame[['model', 'roc_auc', 'average_precision', 'f1', 'balanced_accuracy', 'mcc']]

# %%
benchmark.study_summary
